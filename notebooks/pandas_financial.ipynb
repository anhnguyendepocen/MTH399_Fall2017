# %% [markdown]
# # pandas RIDE financial analysis

# %%
import re
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Modify the following code to read the RI 2016 Uniform Charter of Accounts data from the Rhode Island Department of Education Consolidated District Financial Database
#
# See:
#
# http://www.ride.ri.gov/FundingFinance/SchoolDistrictFinancialData/UniformChartofAccounts.aspx#18211078-statewide-consolidated-district-financial-databases
#
# Call the dataframe:  uca

# %%
epa = pd.read_csv("../epa.csv")
print(epa.shape)
epa.head()
# Out:
# (2884, 50)
#      yr  mfr      mfr name  bidx        vid  cfg      carline car/truck  cid  \
# 0  2009   20  Chrysler LLC     1  L8JCD8152    0  JOURNEY 2WD         T  215
# 1  2009   20  Chrysler LLC     1  L8JCD8152    0  JOURNEY 2WD         T  215
# 2  2009   20  Chrysler LLC     3  L8JCD8152    1  JOURNEY 4WD         T  215
# 3  2009   20  Chrysler LLC     3  L8JCD8152    1  JOURNEY 4WD         T  215
# 4  2009   20  Chrysler LLC     4  L7JSC0243    2  JOURNEY 2WD         T  144
#
#   police   ...    target-a  target-b  target-c  set-a   set-b    set-c  \
# 0      N   ...       37.74    0.6338   0.02404  13.53  0.1037  0.02585
# 1      N   ...       37.74    0.6338   0.02404  13.53  0.1037  0.02585
# 2      N   ...       37.74    0.6338   0.02404  13.53  0.1037  0.02585
# 3      N   ...       37.74    0.6338   0.02404  13.53  0.1037  0.02585
# 4      N   ...       27.99    0.5576   0.02097  10.83  0.1288  0.01811
#
#    engine code    eng family vpc  cstdwn
# ...

# %% [markdown]
# ## Modify the following code to group field counts by district

# %%
epa.groupby(epa['mfr name']).count()
# Out:
#                                         yr  mfr  bidx  vid  cfg  carline  \
# mfr name
# ASTON MARTIN                            14   14    14   14   14       14
# AUDI                                   192  192   192  192  192      192
# BENTLEY MOTORS LTD.                     12   12    12   12   12       12
# BMW                                    137  137   137  137  137      137
# Chrysler LLC                           133  133   133  133  133      133
# FERRARI                                 12   12    12   12   12       12
# FUJI HEAVY IND                          73   73    73   73   73       73
# Ford Motor Company                     349  349   349  349  349      349
# GENERAL MOTORS                         428  428   428  428  428      428
# GM Daewoo Auto and Technology Company    6    6     6    6    6        6
# HONDA                                  100  100   100  100  100      100
# HYUNDAI                                 60   60    60   60   60       60
# ...

# %% [markdown]
# ## Use the dir() function  to display the attributes and member functions of the dataframe class

# %%
#

# %% [markdown]
# ## Print a list of the column names in dataframe uca

# %%
#

# %% [markdown]
# ## Use the groupby() function to list budget totals by district

# %%
#

# %% [markdown]
# ## Create a new column in uca called 'variance'.  Define it as budget-actual.

# %%
#

# %% [markdown]
# ## use groupby to compute the total variance by district

# %%
#
